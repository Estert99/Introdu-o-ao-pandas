# %% [markdown]
# <a href="https://colab.research.google.com/github/Estert99/Introdu-o-ao-pandas/blob/main/BOOTCAMP_Analise_de_dados(exercicios).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("pop_duration.txt",sep= "\t")

print("Colunas encontradas:", df.columns.tolist())
print("\nPrimeiras linhas do ficheiro:")
print(df.head())
# Out:
# Colunas encontradas: ['0         92.851388']
#
# Primeiras linhas do ficheiro:
#    0         92.851388
# 0  4        193.776327
# 1  8          3.161000
# 2  11         0.000000
# 3  13         2.000000
# 4              ...

# %%
import pandas as pd #importanto a bibliote pandas e atribuindo um um apelido.

#preparando os dados e os nomes das colunas
#cada coluna contem um pais e sua capital

atlas = [ #a variavel 'atlas' recebe a lista
         ['France' , 'Paris'], #cada linha da lista precisa ser finalizada com uma ,
         ['Russia','Moscow'],
         ['china', 'Pequin'],
         ['mexico','Cidade do Mexico'],
         ['Egito', 'Cairo'],




]

geography = ['country' , 'capital'] #essa variavel recebe as colunas e linha

# fazendo um DataFrame
world_map = pd.DataFrame (data=atlas , columns = geography)

print(world_map.dtypes) #imprime o atributo dtypes
print(world_map.columns) #imprime o atributo columns
print(world_map.shape) #imprime o atributo shape
print(world_map.info()) #imprime todos os atributos de uma so vez
print(world_map.head()) #imprime os dados na tela
# Out:
# country    object
# capital    object
# dtype: object
# Index(['country', 'capital'], dtype='object')
# (5, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  5 non-null      object
#  1   capital  5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes
# None
#   country           capital
# 0  France             Paris
# 1  Russia            Moscow
# 2   china            Pequin
# 3  mexico  Cidade do Mexico
# 4   Egito             Cairo

# %% [markdown]
# Crie uma lista de listas intituladas state_animals. Cada lista contém dois valores string: o nome de um estado e seu animal correspondente. A lista state_animals deve ter dez elementos.
#
# Em seguida, crie uma lista chamada col_names com dois elementos: os nomes das colunas 'state' e 'animal'.
#
# A etapa final é criar um DataFrame com state_animals como valores e col_names como nomes das colunas. Armazene este DataFrame na variável df e imprima-o.

# %%
import pandas as pd

state_animals = [
    ['Alabama','Black Bear'],
    ['Alaska', 'Moose'],
    ['Arizona','Ringtail'],
    ['California', 'Grizzly Bear'],
    ['Colorado','Rocky Mt. bighorn sheep'],
    ['Connecticut','sperm whale'],
    ['Delaware' , "Gray Fox"],
    ['Florida', 'Manatee'],
    ['Georgia', 'White-tailed deer'],



]

col_names = ['state', 'animal']

df = pd.DataFrame (data= state_animals , columns= col_names)

print(df)
# Out:
#          state                   animal
# 0      Alabama               Black Bear
# 1       Alaska                    Moose
# 2      Arizona                 Ringtail
# 3   California             Grizzly Bear
# 4     Colorado  Rocky Mt. bighorn sheep
# 5  Connecticut              sperm whale
# 6     Delaware                 Gray Fox
# 7      Florida                  Manatee
# 8      Georgia        White-tailed deer

# %% [markdown]
# **PRE PROCESSAMENTO DE DADOS **
