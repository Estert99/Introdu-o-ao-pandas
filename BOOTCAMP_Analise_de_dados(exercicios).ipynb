# %% [markdown]
# <a href="https://colab.research.google.com/github/Estert99/Introdu-o-ao-pandas/blob/main/BOOTCAMP_Analise_de_dados(exercicios).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("pop_duration.txt",sep= "\t")

print("Colunas encontradas:", df.columns.tolist())
print("\nPrimeiras linhas do ficheiro:")
print(df.head())
# Out:
# Colunas encontradas: ['0         92.851388']
#
# Primeiras linhas do ficheiro:
#    0         92.851388
# 0  4        193.776327
# 1  8          3.161000
# 2  11         0.000000
# 3  13         2.000000
# 4              ...
